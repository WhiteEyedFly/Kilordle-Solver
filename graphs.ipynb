# %%
import numpy as np
import pandas as pd

optimal = ["aback", "affix", "aglow", "banjo", "crump", "djinn", "embog", "enzym", "expel", "fixer", 
           "glyph", "hydro", "itchy", "jambu", "kvell", "luvvy", "mekka", "nkosi", "optic", "pzazz",
           "qajaq", "rowdy", "schwa", "squib", "twixt", "usque", "vuggs", "whiff", "ydrad", "zesty"]

data = {
    "Approach": ["Greedy 1", "Greedy 2", "Greedy 3", "kSS", "betterWord", "kJS", "0In", "D&C", "satSolver", "satSolver2", "cpModel"],
    "MinFullCover": [34,38,42,200,46,63,65,48,34,32,30],
    "MaxCoverageAt30": [0,0,0,0,91,0,0,0,91,95,100],
    "HasRandomElement": [0,0,0,2,1,1,1,0,1,0,1]
}

# Normalise the data for easier viewing
for point in range(len(data["MinFullCover"])):
    data["MinFullCover"][point] = 100*data["MinFullCover"][point]/30
for point in range(len(data["HasRandomElement"])):
    data["HasRandomElement"][point] = data["HasRandomElement"][point]*50

print("kilordleInitialSolver and kilordleSuperSolver were too slow to produce analysable results but theoretically solved the problem")
print("Data is presented as percentages of the optimal value reached")
print("The best solution found was 100% coverage with 30 words using the cpModel SAT Solver:")
print(optimal[0:14])
print(optimal[15:29])

df = pd.DataFrame(data)

#print(df)
df.plot.barh(x="Approach")
# Out:
# kilordleInitialSolver and kilordleSuperSolver were too slow to produce analysable results but theoretically solved the problem
# Data is presented as percentages of the optimal value reached
# The best solution found was 100% coverage with 30 words using the cpModel SAT Solver:
# ['aback', 'affix', 'aglow', 'banjo', 'crump', 'djinn', 'embog', 'enzym', 'expel', 'fixer', 'glyph', 'hydro', 'itchy', 'jambu']
# ['luvvy', 'mekka', 'nkosi', 'optic', 'pzazz', 'qajaq', 'rowdy', 'schwa', 'squib', 'twixt', 'usque', 'vuggs', 'whiff', 'ydrad']
# <Axes: ylabel='Approach'>
